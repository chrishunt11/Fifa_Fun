# %% [markdown]
# # FIFA

# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
df = pd.read_csv('Data/fifa_data.csv')
df.drop(columns='Unnamed: 0', inplace=True)
pd.set_option('display.max_columns',100)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
# Taking a look at the amount of rows, columns in the dataset
print(f'There are {df.shape[0]} columns and {df.shape[1]} rows in this dataset.')
# Out:
# There are 18207 columns and 88 rows in this dataset.

# %%
# Looking at the basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %% [markdown]
# ## Fixing Inconsistencies

# %%
df['Wage'] = df['Wage'].str.replace('€', '').str.replace('K', '').astype(float)
df['Wage'] = df['Wage'].copy().sort_values(ascending=False)

# %%
df['Weight'] = df['Weight'].str.replace('lbs', '').astype(float)

# %%
import numpy as np

# Function to convert feet to inches
def feet_to_inches(height):
    if pd.notna(height):
        if "'" in height:  # Check if the string contains "'"
            feet, inches = map(int, height.split("'"))
            total_inches = feet * 12 + inches
            return total_inches
        elif isinstance(height, (int, float)):  # Check if it's a numeric value
            return np.nan  # Return NaN for numeric values
        else:
            return np.nan  # Return NaN for unexpected cases
    else:
        return np.nan  # Return NaN if it's already NaN

# Convert 'Height' column to inches
df['Height'] = df['Height'].apply(feet_to_inches)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Which team has the Highest/Lowest average overall?

# %%
# Calculate average overall ratings for each club
club_ratings = df.groupby('Club')['Overall'].mean()

# Identify the club with the highest and lowest average overall ratings
best_club, best_rating = club_ratings.idxmax(), club_ratings.max()
worst_club, worst_rating = club_ratings.idxmin(), club_ratings.min()

# Print the results
print(f"Highest Average Overall Rating: {best_club} ({best_rating:.2f})")
print(f"Lowest Average Overall Rating: {worst_club} ({worst_rating:.2f})")
# Out:
# Highest Average Overall Rating: Juventus (82.28)
# Lowest Average Overall Rating: Bray Wanderers (53.65)

# %%
import matplotlib.pyplot as plt

# Make sure 'Overall' column is of numeric type
df['Overall'] = pd.to_numeric(df['Overall'], errors='coerce')

# Selecting the top 10 clubs
top_10_clubs = club_ratings.nlargest(10)

# Reset the index for plotting
top_10_clubs = top_10_clubs.reset_index()

# Example color palette
colors = ['skyblue' if club != best_club else 'orange' for club in top_10_clubs['Club']]

# Plotting the bar chart for the top 10 clubs
plt.figure(figsize=(12, 8), dpi=100)
plt.bar(top_10_clubs['Club'], top_10_clubs['Overall'], color=colors, label='Highest Average Overall Rating')
plt.title('Top 10 Clubs by Average Overall Ratings', fontsize=16)
plt.xlabel('Club', fontsize=12)
plt.ylabel('Average Overall Rating', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.annotate(f'{best_club} ({best_rating:.2f})', 
             xy=(0, best_rating), xytext=(0, best_rating + 5),
             arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Which team has the Highest/Lowest average Wage?

# %%
# Calculate average wages for each club
club_wages = df.groupby('Club')['Wage'].mean()

# Identify the club with the highest and lowest average wages
highest_club_wage, highest_wage = club_wages.idxmax(), club_wages.max()
lowest_club_wage, lowest_wage = club_wages.idxmin(), club_wages.min()

# Print the results
print(f"The club with the highest average wages is {highest_club_wage}, boasting an average wage of €{highest_wage:.0f},000.")
print(f"On the flip side, the club with the lowest average wage is {lowest_club_wage}, showcasing an average of €{lowest_wage:.0f},000.")
# Out:
# The club with the highest average wages is Real Madrid, boasting an average wage of €152,000.
# On the flip side, the club with the lowest average wage is AEK Athens, showcasing an average of €1,000.

# %%
# Selecting the top 10 clubs
top_10_wages = club_wages.nlargest(10)

# Reset the index for plotting
top_10_wages = top_10_wages.reset_index()

# Example color palette
colors = ['skyblue' if club != highest_club_wage else 'orange' for club in top_10_wages['Club']]

# Plotting the bar chart for the top 10 clubs
plt.figure(figsize=(12, 8), dpi=100)
plt.bar(top_10_wages['Club'], top_10_wages['Wage'], color=colors, label='Highest Average Wage')
plt.title('Top 10 Clubs by Average Wage')
plt.xlabel('Club')
plt.ylabel('Average Wage (by hundreds in €)')
plt.xticks(rotation=45, ha='right')
plt.annotate(f'{highest_club_wage} (€{highest_wage:.0f}K)', 
             xy=(0, highest_wage), xytext=(0, highest_wage + 10),
             arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Which team has the highest average Skill Moves?

# %%
# Calculate average skill moves for each club
club_skills = df.groupby('Club')['Skill Moves'].mean()

# Identify the club with the highest and lowest average skill moves
best_club, best_skills = club_skills.idxmax(), club_skills.max()
worst_club, worst_skills = club_skills.idxmin(), club_skills.min()

# Print the results
print(f"Highest Average Skill Moves: {best_club} ({best_skills:.2f})")
print(f"Lowest Average Skill Moves: {worst_club} ({worst_skills:.2f})")
# Out:
# Highest Average Skill Moves: Paris Saint-Germain (3.10)
# Lowest Average Skill Moves: Bray Wanderers (1.91)

# %%
# Calculate average skill moves for each club
club_skill_moves = df.groupby('Club')['Skill Moves'].mean()

# Identify the club with the highest and lowest average skill moves
best_club_skill_moves = club_skill_moves.idxmax()
best_skill_moves = club_skill_moves.max()

worst_club_skill_moves = club_skill_moves.idxmin()
worst_skill_moves = club_skill_moves.min()

# Selecting the top 10 clubs
top_10_skill_moves = club_skill_moves.nlargest(10)

# Reset the index for plotting
top_10_skill_moves = top_10_skill_moves.reset_index()

# Example color palette
colors_skill_moves = ['skyblue' if club != best_club_skill_moves else 'orange' for club in top_10_skill_moves['Club']]

# Plotting the bar chart for the top 10 clubs
plt.figure(figsize=(12, 6), dpi=100)
plt.bar(top_10_skill_moves['Club'], top_10_skill_moves['Skill Moves'], color=colors_skill_moves, label='Highest Average Skill Moves')
plt.title('Top 10 Clubs by Average Skill Moves')
plt.xlabel('Club')
plt.ylabel('Average Skill Moves')
plt.xticks(rotation=45, ha='right')
plt.annotate(f'{best_club_skill_moves} ({best_skill_moves:.2f} Skill Moves)', 
             xy=(0, best_skill_moves), xytext=(0, best_skill_moves + .25),
             arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Distribution of Age/Height/Weight

# %%
# Calculate and display average player metrics
average_height = df['Height'].mean()
average_weight = df['Weight'].mean()
average_age = df['Age'].mean()

tallest = df['Height'].max()
shortest = df['Height'].min()
oldest = df['Age'].max()
youngest = df['Age'].min()

print(f'Oldest player: {oldest} years old')
print(f'Youngest player: {youngest} years old\n')

print(f'Average player height: {average_height:.2f} inches')
print(f'Average player weight: {average_weight:.2f} pounds')
print(f'Average player age: {average_age:.2f} years')
# Out:
# Oldest player: 45 years old
# Youngest player: 16 years old
#
# Average player height: 71.36 inches
# Average player weight: 165.98 pounds
# Average player age: 25.12 years

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the DataFrame by Height
df_sorted_height = df.sort_values('Height', ascending=True)

# Plotting the distribution of Age
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Age')

# Plotting the distribution of Height
plt.subplot(2, 2, 2)
sns.histplot(df_sorted_height['Height'], bins=20, kde=True, color='salmon')
plt.title('Distribution of Height')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Sort the DataFrame by Weight
df_sorted_weight = df.sort_values('Weight', ascending=False)

# Plotting the distribution of Weight using Seaborn histplot
plt.subplot(2, 2, 3)
sns.histplot(df_sorted_weight['Weight'], bins=range(100, 275, 5), kde=True, color='lightgreen', edgecolor='black')
plt.title('Distribution of Weight')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Do players with higher skill move ratings have higher overall ratings?

# %%
# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='Skill Moves', y='Overall', data=df, scatter_kws={'s': 20, 'alpha': 0.5}, line_kws={'color': 'red'})
plt.title('Skill Moves vs Overall Rating')
plt.xlabel('Skill Moves')
plt.ylabel('Overall Rating')
plt.grid(axis='both', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ### Distribution of Goal Keepers Attributes

# %%
# Filter only goalkeeper data
goalkeepers_df = df[df['Position'] == 'GK']

# Select goalkeeper attributes
goalkeeper_attributes = ['GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

# Plotting the distribution of goalkeeper attributes
plt.figure(figsize=(20, 10))
for attribute in goalkeeper_attributes:
    plt.hist(goalkeepers_df[attribute], bins=20, alpha=0.7, label=attribute)

plt.title('Distribution of Goalkeeper Attributes')
plt.xlabel('Attribute Value')
plt.ylabel('Number of Goalkeepers')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ### Which team has the greatest potential?

# %%
potential = df.groupby('Club')['Potential'].max()
potential_sorted = potential.sort_values(ascending=False)

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Make sure 'Potential' column is of numeric type
df['Potential'] = pd.to_numeric(df['Potential'], errors='coerce')

# Calculate maximum potential ratings for each club
potential = df.groupby('Club')['Potential'].mean()

# Identify the club with the highest and lowest maximum potential ratings
best_club_potential, best_potential = potential.idxmax(), potential.max()
worst_club_potential, worst_potential = potential.idxmin(), potential.min()

# Selecting the top 10 clubs
top_10_potential = potential.nlargest(10)

# Reset the index for plotting
top_10_potential = top_10_potential.reset_index()

# Example color palette
colors_potential = ['skyblue' if club != best_club_potential else 'orange' for club in top_10_potential['Club']]

# Plotting the bar chart for the top 10 clubs
plt.figure(figsize=(12, 6), dpi=100)
plt.bar(top_10_potential['Club'], top_10_potential['Potential'], color=colors_potential, label='Highest Team Potential')
plt.title('Top 10 Clubs by Potential Ratings')
plt.xlabel('Club')
plt.ylabel('Maximum Potential Rating')
plt.xticks(rotation=45, ha='right')
plt.annotate(f'{best_club_potential} ({best_potential:.2f} Potential)', 
             xy=(0, best_potential), xytext=(0, best_potential + 10),
             arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Are taller players better?

# %%
## Taller the player, higher the overall?
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame
# Make sure 'Height' column is of numeric type
df['Height'] = pd.to_numeric(df['Height'], errors='coerce')

# Plotting a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Height', y='Overall', data=df, alpha=0.5)
plt.title('Height vs Overall Rating')
plt.xlabel('Height (in inches)')
plt.ylabel('Overall Rating')
plt.grid(axis='both', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ### Correlation Map

# %%
# Make sure all columns are of numeric type
df_numeric = df.select_dtypes(include='number')

# Calculate the correlation matrix
correlation_matrix = df_numeric.corr()

# Create a heatmap showing only the lower triangle
plt.figure(figsize=(18, 12))
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Adjust the font size
annot_kws = {'fontsize': 6}

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, mask=mask, annot_kws=annot_kws)

# Rotate x-axis labels
plt.xticks(rotation=66, ha='right')

plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd

# Assuming 'df' is your DataFrame

# Sort the DataFrame by the 'Special' column in descending order
df_sorted_special = df.sort_values(by='Special', ascending=False)

# Group by 'Name' and 'Special', then select the top 10 for each group
top_10_players_special = df_sorted_special.groupby(['Name', 'Special']).head(10)

# Sort the DataFrame by the 'Overall' column in descending order
df_sorted_overall = df.sort_values(by='Overall', ascending=False)

# Group by 'Name' and 'Special', then select the top 10 for each group
top_10_players_overall = df_sorted_overall.groupby(['Name', 'Special']).head(10)

# Add a prefix to differentiate between 'Special' and 'Overall' columns
top_10_players_special = top_10_players_special.add_prefix('Special_')
top_10_players_overall = top_10_players_overall.add_prefix('Overall_')

# Display the concatenated result with Special_Overall and Overall_Overall sorted
result = pd.concat([top_10_players_special[['Special_Name', 'Special_Special', 'Special_Overall']],
                    top_10_players_overall[['Overall_Name', 'Overall_Special', 'Overall_Overall']]], axis=1)

# Sort the DataFrame by 'Special_Overall' and 'Overall_Overall' in descending order
result = result.sort_values(by=['Special_Overall', 'Overall_Overall'], ascending=[False, False])

# Display the result
result.head(20)
# Out:
#          Special_Name  Special_Special  Special_Overall       Overall_Name  \
# 1   Cristiano Ronaldo             2228               94  Cristiano Ronaldo
# 0            L. Messi             2202               94           L. Messi
# 2           Neymar Jr             2143               92          Neymar Jr
# 7           L. Suárez             2346               91          L. Suárez
# 4        K. De Bruyne             2281               91       K. De Bruyne
# 6           L. Modrić             2280               91          L. Modrić
# 8        Sergio Ramos             2201               91       Sergio Ramos
# 5           E. Hazard             2142               91          E. Hazard
# 3              De Gea             1471               91             De Gea
# 11           T. Kroos             2190               90           T. Kroos
# 10     R. Lewandowski             2152               90     R. Lewandowski
# ...

# %%
top_10_players_overall[['Overall_Name','Overall_Overall']].head(10)
# Out:
#          Overall_Name  Overall_Overall
# 0            L. Messi               94
# 1   Cristiano Ronaldo               94
# 2           Neymar Jr               92
# 3              De Gea               91
# 4        K. De Bruyne               91
# 5           E. Hazard               91
# 6           L. Modrić               91
# 7           L. Suárez               91
# 8        Sergio Ramos               91
# 12           D. Godín               90

# %%
top_10_players_special[['Special_Name','Special_Special']].head(10)
# Out:
#       Special_Name  Special_Special
# 7        L. Suárez             2346
# 4     K. De Bruyne             2281
# 6        L. Modrić             2280
# 36         G. Bale             2279
# 35         Marcelo             2279
# 101  R. Nainggolan             2278
# 428       M. Acuña             2265
# 85        D. Alaba             2261
# 112    Alex Telles             2259
# 258    A. Florenzi             2253
